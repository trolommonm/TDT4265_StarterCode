# %%
import sys, os
sys.path.append(os.path.dirname(os.getcwd())) # Include ../SSD in path
import tops
from tops.config import instantiate
import pathlib
from ssd.utils import load_config
from plot_utils import plot

# %%
task21_logs = tops.logger.read_logs(pathlib.Path("/work/snotra/adtan/ssd_outputs/task21_config/"))
task22_logs = tops.logger.read_logs(pathlib.Path("/work/snotra/adtan/ssd_outputs/task22_config/"))

# %%
# plot mAP@0.5:0.95
fig, ax = plot([task21_logs, task22_logs], ["Task 2.1", "Task 2.2"], "metrics/mAP")
fig.legend()

# %%
print("Highest mAP@0.5:0.95 reach for Task 2.2: ", max([entry["metrics/mAP"] for entry in task22_logs if "metrics/mAP" in entry]))
# Out:
# Highest mAP@0.5:0.95 reach for Task 2.2:  0.0504822482558437

# %%
# plot regression loss
fig, ax = plot([task21_logs, task22_logs], ["Task 2.1", "Task 2.2"], "loss/regression_loss")
fig.legend()

# %%
# plot classification loss
fig, ax = plot([task21_logs, task22_logs], ["Task 2.1", "Task 2.2"], "loss/classification_loss")
fig.legend()

# %%
# plot classification loss
fig, ax = plot([task21_logs, task22_logs], ["Task 2.1", "Task 2.2"], "loss/total_loss")
fig.legend()

# %%
cfg = load_config("../configs/task22_config.py")
model = instantiate(cfg.model)

num_parameters = sum(p.numel() for p in model.parameters())
num_trainable_parameters = sum(p.numel() for p in model.parameters() if p.requires_grad)

print("Total number of parameters: ", num_parameters)
print("Total number of trainable parameters: ", num_trainable_parameters)
# Out:
# NOTE! Installing ujson may make loading annotations faster.
# It looks like you are currently working on the server, with a 'working directory' in: /work/snotra/adtan
# Saving all SSD outputs to: /work/snotra/adtan/ssd_outputs
# Found dataset directory in: /work/datasets/mnist_object_detection/train
# Found dataset directory in: /work/datasets/mnist_object_detection/val
# Found dataset directory in: /work/datasets/tdt4265_2022
# Found dataset file in: /work/datasets/tdt4265_2022/train_annotations.json
# Found dataset directory in: /work/datasets/tdt4265_2022
# Found dataset file in: /work/datasets/tdt4265_2022/val_annotations.json
# Total number of parameters:  2811680
# Total number of trainable parameters:  2549920

# %%
# %cd ../configs
# Out:
# /home/adtan/project/assignment4/SSD/configs

# %%
# !python ../runtime_analysis.py task22_config.py
# Out:
# NOTE! Installing ujson may make loading annotations faster.
# It looks like you are currently working on the server, with a 'working directory' in: /work/snotra/adtan
# Saving all SSD outputs to: /work/snotra/adtan/ssd_outputs
# Found dataset directory in: /work/datasets/mnist_object_detection/train
# Found dataset directory in: /work/datasets/mnist_object_detection/val
# Found dataset directory in: /work/datasets/tdt4265_2022
# Found dataset file in: /work/datasets/tdt4265_2022/train_annotations.json
# Found dataset directory in: /work/datasets/tdt4265_2022
# Found dataset file in: /work/datasets/tdt4265_2022/val_annotations.json
# 2022-05-07 22:04:11,225 [INFO ] Loaded checkpoint from /work/snotra/adtan/ssd_outputs/task22_config/checkpoints/2500.ckpt
# ...
